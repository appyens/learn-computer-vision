# %%
from PIL import Image
import matplotlib.image as mpimg
import matplotlib.pylab as plt
import imageio
import cv2
import glob

# %%
# Read image with pillow
im = Image.open('../resources/snigdha.jpg')

# %%
print(im.width, im.height, im.mode, im.format, type(im))
# Out:
# 1920 1080 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
im.show()

# %%
# Read image with scipy
im2 = imageio.imread('../resources/mahalaxmi.jpg')
# as numpy array

# %%
print(type(im2), im2.shape, im2.dtype)
# Out:
# <class 'imageio.core.util.Array'> (600, 800, 3) uint8

# %%
plt.figure(figsize=(10,10))
plt.imshow(im2)
plt.axis('off')
plt.show()

# %%
# Read images with matplotlib
im3 = mpimg.imread('../resources/oneplus.jpg')
# as numpy array

# %%
plt.figure(figsize=(10, 10))
plt.imshow(im3)
plt.axis('off')
plt.show()

# %%
# read in multiple images from folder
images = [cv2.imread(file) for file in glob.glob('../resources/*.jpg')]

# %%
for im in images:
    plt.imshow(im)

# %%
# Read in files with diff extensitons

imdir = '../resources/'
ext = ['jpg']
files = []
[files.extend(glob.glob(imdir + '*.' + e)) for e in ext]
images2 = [cv2.imread(file) for file in files]

# %%
plt.imshow(images2[0])
